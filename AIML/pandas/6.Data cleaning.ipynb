# %%
#handling missing data

#Topic 1 Check missing value
#isnull() returns a DataFrame of Boolean value where True represents missing data (NaN). 
#This is simple if we want to find and fill missing data in a dataset.

import pandas as pd
import numpy as np

d = {'First Score': [100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score': [np.nan, 40, 80, 98]}
df = pd.DataFrame(d)

mv = df.isnull()

print(mv)
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
#Check the gender column and print the rows contain missing data
import pandas as pd
d = pd.read_csv("employees.csv")

bool_series = pd.isnull(d["Gender"])
missing_gender_data = d[bool_series]
print(missing_gender_data)
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management                  Team
# 20               True                 Legal
# 22               True       Client Services
# 27              False                 Legal
# 31              False               Product
# 41               True  Business Development
# ..                ...                   ...
# 961             False                 Legal
# 972              True                 Sales
# 985             False                 Legal
# 989             False                 Legal
# 995             False          Distribution
#
# [145 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

data = {'Name': ['Amit', 'Sita', np.nan, 'Raj'],
        'Age': [25, np.nan, 22, 28]}

df = pd.DataFrame(data)

# Check for missing values using isna()
print(df.isna())
# Out:
#     Name    Age
# 0  False  False
# 1  False   True
# 2   True  False
# 3  False  False

# %%
#using notnull()

d = {'First Score': [100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score': [np.nan, 40, 80, 98]}
df = pd.DataFrame(d)

nmv = df.notnull()

print(nmv)
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
#Filter data with non missing values

d = pd.read_csv("employees.csv")

nmg = pd.notnull(d["Gender"])

nmgd= d[nmg]

display(nmgd)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 994              True             Marketing
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [855 rows x 8 columns]

# %%
### Very important

##filling missing vlaues



d = {'First Score': [100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score': [np.nan, 40, 80, 98]}
df = pd.DataFrame(d)

df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
df.fillna(method='pad')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4252\915722415.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
df.ffill()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
df.bfill()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
import pandas as pd
import numpy as np
d = pd.read_csv("employees.csv")
d["Gender"] = d["Gender"].fillna('No Gender')

d[10:25]
# Out:
#    First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise     Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie     Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon       Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary       Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly     Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian     Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy       Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn       Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana     Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna     Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois  No Gender   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew       Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua  No Gender    3/8/2012         1:58 AM   90816   18.816
# 23        NaN       Male   6/14/2012         4:19 PM  125792    5.042
# 24       John       Male    7/1/1992        10:08 PM   97950   13.873
#
#    Senior Management             Team
# 10              True              NaN
# 11              True            Legal
# 12              True  Human Resources
# 13             False            Sales
# 14              True          Finance
# 15             False          Product
# 16             False  Human Resources
# 17             False          Product
# 18             False  Client Services
# 19             False          Product
# 20              True            Legal
# 21             False        Marketing
# 22              True  Client Services
# 23               NaN              NaN
# 24             False  Client Services

# %%
#replace

import pandas as pd
import numpy as np

data = pd.read_csv("employees.csv")
data[10:25]
data.replace(to_replace=np.nan, value=-99)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     -99  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   -99
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
#interpolate()

import pandas as pd
import numpy as np

data = {'Score': [10, np.nan, 30, np.nan, 50]}
df = pd.DataFrame(data)
df['Score'] = df['Score'].interpolate()

print(df)
# Out:
#    Score
# 0   10.0
# 1   20.0
# 2   30.0
# 3   40.0
# 4   50.0

# %%
#Example2

import pandas as pd
   
df = pd.DataFrame({"A": [12, 4, 5, None, 1], 
                   "B": [None, 2, 54, 3, None], 
                   "C": [20, 16, None, 3, 8], 
                   "D": [14, 3, None, None, 6]})  

k=df.interpolate(method ='linear', limit_direction ='forward')
print(df)
print(k)
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %%
###Droppping missing values
## important


import pandas as pd
import numpy as np

dict = {'First Score': [100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score': [52, 40, 80, 98],
        'Fourth Score': [np.nan, np.nan, np.nan, 65]}
df = pd.DataFrame(dict)
print(df)
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
#dropping rows with all null values

dict = {'First Score': [100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score': [52, np.nan, 80, 98],
        'Fourth Score': [np.nan, np.nan, np.nan, 65]}
df = pd.DataFrame(dict)
print(df)

df.dropna(how='all')
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0           NaN
# 1          NaN           NaN          NaN           NaN
# 2          NaN          45.0         80.0           NaN
# 3         95.0          56.0         98.0          65.0
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0           NaN
# 2          NaN          45.0         80.0           NaN
# 3         95.0          56.0         98.0          65.0

# %%
#Drop colums that contain atleast one value

dict = {'First Score': [100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, np.nan, 56],
        'Third Score': [52, np.nan, 80, 98],
        'Fourth Score': [60, 67, 68, 65]}
df = pd.DataFrame(dict)
print(df)


df.dropna(axis=0)   #rows
df.dropna(axis=0)   #colums
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 1          NaN           NaN          NaN            67
# 2          NaN           NaN         80.0            68
# 3         95.0          56.0         98.0            65
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 3         95.0          56.0         98.0            65

# %%
#Dropping Rows with Missing Values in CSV Files

import pandas as pd
d = pd.read_csv("employees.csv")

nd = d.dropna(axis=0, how='any')

print("Old data frame length:", len(d))
print("New data frame length:", len(nd))
print("Rows with at least one missing value:", (len(d) - len(nd)))
# Out:
# Old data frame length: 1000
# New data frame length: 764
# Rows with at least one missing value: 236

# %%
#Topic 2 : Remove duplicates

import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Alice", "David"],
    "Age": [25, 30, 25, 40],
    "City": ["NY", "LA", "NY", "Chicago"]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

df_cleaned = df.drop_duplicates()

print("\nModified DataFrame (no duplicates)")
print(df_cleaned)
# Out:
# Original DataFrame:
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   30       LA
# 2  Alice   25       NY
# 3  David   40  Chicago
#
# Modified DataFrame (no duplicates)
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   30       LA
# 3  David   40  Chicago

# %%
#dropping duplicates based on specific colums

import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Alice', 'David'],
    'Age': [25, 30, 25, 40],
    'City': ['NY', 'LA', 'SF', 'Chicago']
})

df_cleaned = df.drop_duplicates(subset=["Name"])

print(df_cleaned)
# Out:
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   30       LA
# 3  David   40  Chicago

# %%
#keeping last occurrence

import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Alice', 'David'],
    'Age': [25, 30, 25, 40],
    'City': ['NY', 'LA', 'NY', 'Chicago']
})

df_cleaned= df.drop_duplicates(keep='last')
print(df_cleaned)
# Out:
#     Name  Age     City
# 1    Bob   30       LA
# 2  Alice   25       NY
# 3  David   40  Chicago

# %%
# remove all rows that are duplicate
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Alice', 'David'],
    'Age': [25, 30, 25, 40],
    'City': ['NY', 'LA', 'NY', 'Chicago']
})
df_cleaned = df.drop_duplicates(keep=False)
print(df_cleaned)
# Out:
#     Name  Age     City
# 1    Bob   30       LA
# 3  David   40  Chicago

# %%
# modifing original dataframe directly all above create a duplicate  record


df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Alice', 'David'],
    'Age': [25, 30, 25, 40],
    'City': ['NY', 'LA', 'NY', 'Chicago']
})
df.drop_duplicates(inplace=True)
print(df)
# Out:
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   30       LA
# 3  David   40  Chicago

# %%
# If two rows have the same "Name" and "City", one of them will be dropped.

# Other columns are ignored for the duplicate check.


import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Alice", "David", "Bob"],
    "Age": [25, 20, 25, 40, 30],
    "City": ["NY", "LA", "NY", "Chicago", "LA"]
}

df = pd.DataFrame(data)
df_cleaned = df.drop_duplicates()

df_cleaned = df.drop_duplicates(subset=["Name", "City"])
print(df)

print(df_cleaned)
# Out:
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   20       LA
# 2  Alice   25       NY
# 3  David   40  Chicago
# 4    Bob   30       LA
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   20       LA
# 3  David   40  Chicago

# %%
# Topic 3 pandas change datatype
#using as type

import pandas as pd

data = {'Name': ['John', 'Alice', 'Bob', 'Eve', 'Charlie'], 
        'Age': [25, 30, 22, 35, 28], 
        'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'], 
        'Salary': [50000, 55000, 40000, 70000, 48000]}

df = pd.DataFrame(data)
print(df.dtypes)

# Convert 'Age' column to float type
df['Age'] = df['Age'].astype(float)
print(df.dtypes)
# Out:
# Name      object
# Age        int64
# Gender    object
# Salary     int64
# dtype: object
# Name       object
# Age       float64
# Gender     object
# Salary      int64
# dtype: object

# %%
#Tpoic 4 : Drop empty columns in pandas

import numpy as np
import pandas as pd

df = pd.DataFrame({'FirstName': ['Vipul', 'Ashish', 'Milan'],
                            "Gender": ["", "", ""],
                            "Age": [0, 0, 0]})
df['Department'] = np.nan      #Create a new column named Department

print(df)
# Out:
#   FirstName Gender  Age  Department
# 0     Vipul           0         NaN
# 1    Ashish           0         NaN
# 2     Milan           0         NaN

# %%
#topic 5 String manipulation in pandas

import pandas as pd
import numpy as np

data = {'Names': ['Gulshan', 'Shashank', 'Bablu', 'Abhishek', 'Anand', np.nan, 'Pratap'],
        'City': ['Delhi', 'Mumbai', 'Kolkata', 'Delhi', 'Chennai', 'Bangalore', 'Hyderabad']}

df = pd.DataFrame(data)
print(df)


# print(df['Names'].str.lower())
# print(df['Names'].str.upper())
# print(df['Names'].str.strip())
# df['Split_Names'] = df['Names'].str.split('a')
# print(df[['Names', 'Split_Names']])
# print(df['Names'].str.len())
# print("\nafter using cat:")
# print(df['Names'].str.cat(sep=', '))
# print(df['City'].str.get_dummies())
# print(df['Names'].str.startswith('G'))
# print(df['Names'].str.endswith('h'))
# print(df['Names'].str.replace('Gulshan', 'Gaurav'))
# print(df['Names'].str.repeat(2))
# print(df['Names'].str.count('a'))
# print(df['Names'].str.find('a'))
# print(df['Names'].str.findall('a'))
# print(df['Names'].str.islower())
# print(df['Names'].str.isupper())
# print(df['Names'].str.isnumeric())
print(df['Names'].str.swapcase())
# Out:
#       Names       City
# 0   Gulshan      Delhi
# 1  Shashank     Mumbai
# 2     Bablu    Kolkata
# 3  Abhishek      Delhi
# 4     Anand    Chennai
# 5       NaN  Bangalore
# 6    Pratap  Hyderabad
# 0     gULSHAN
# 1    sHASHANK
# 2       bABLU
# 3    aBHISHEK
# 4       aNAND
# 5         NaN
# 6      pRATAP
# Name: Names, dtype: object

# %%
#Topic 6 : Dectect mixed datatypes and fix it.


#Topic 6 : Dectect mixed datatypes and fix it.


# Python program to detect mixed data types in Pandas data frame

# Import the library Pandas
import pandas as pd
  
# Create the pandas DataFrame
data_frame = pd.DataFrame( [['tom', 10], ['nick', '15'], ['juli', 14.5]], columns=['Name', 'Age'])

print(data_frame.info())

# Traverse data frame to detect mixed data types
for column in data_frame.columns:
    print(column,':',pd.api.types.infer_dtype(data_frame[column]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# None
# Name : string
# Age : mixed-integer

# %%
# Python program to fix mixed data types using astype() in Pandas data frame

# Import the library Pandas
import pandas as pd
  
# Create the pandas DataFrame
data_frame = pd.DataFrame( [['tom', 10], ['nick', '15'], ['juli', 14.8]], columns=['Name', 'Age'])

# Transforming mixed data types to single data type
data_frame[column] = data_frame[column].astype(int)

# Traverse data frame to detect data types after fix
for column in data_frame.columns:
    print(column,':',pd.api.types.infer_dtype(data_frame[column]))
# Out:
# Name : string
# Age : integer

# %%
# Python program to fix mixed data types using to_numeric() in Pandas data frame
import pandas as pd

# Create DataFrame
data_frame = pd.DataFrame(
    [['tom', 10], ['nick', '15'], ['juli', 14.8]],
    columns=['Name', 'Age']
)

# Transform mixed data types to single data type
for column in data_frame.columns:
    data_frame[column] = data_frame[column].apply(lambda x: pd.to_numeric(x, errors='ignore'))

# Detect data types after fix
for column in data_frame.columns:
    print(column, ":", pd.api.types.infer_dtype(data_frame[column]))
# Out:
# Name : string
# Age : floating
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5116\2032572412.py:12: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   data_frame[column] = data_frame[column].apply(lambda x: pd.to_numeric(x, errors='ignore'))

# %%
import pandas as pd

# Example DataFrame with mixed types
data_frame = pd.DataFrame({
    'Name': ['Tom', 'Nick', 'Juli'],
    'Age': [10, '15', 14.8],
    'Salary': ['25000', 30000, '35000.50'],
    'Department': ['HR', 'IT', 'Finance']
})

print("🔹 Original Data Types:")
print(data_frame.dtypes, '\n')

# Step 1: Detect mixed-type columns
mixed_columns = []
for col in data_frame.columns:
    inferred = pd.api.types.infer_dtype(data_frame[col])
    if 'mixed' in inferred or inferred in ['string', 'mixed-integer']:
        mixed_columns.append(col)

print("🕵️ Mixed or convertible columns detected:", mixed_columns, '\n')

# Step 2: Fix mixed columns using pd.to_numeric()
for col in mixed_columns:
    data_frame[col] = pd.to_numeric(data_frame[col], errors='ignore')

# Step 3: Show fixed dtypes
print("✅ Fixed Data Types:")
print(data_frame.dtypes, '\n')

# Step 4: Verify data type inference
for col in data_frame.columns:
    print(f"{col} → {pd.api.types.infer_dtype(data_frame[col])}")
# Out:
# 🔹 Original Data Types:
# Name          object
# Age           object
# Salary        object
# Department    object
# dtype: object
#
# 🕵️ Mixed or convertible columns detected: ['Name', 'Age', 'Salary', 'Department']
#
# ✅ Fixed Data Types:
# Name           object
# Age           float64
# Salary        float64
# Department     object
# dtype: object
#
# Name → string
# Age → floating
# Salary → floating
# Department → string
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5116\3541893948.py:25: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   data_frame[col] = pd.to_numeric(data_frame[col], errors='ignore')
